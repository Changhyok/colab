# %% [markdown]
# # Python 기초

# %%
int(3.5)
# Out:
# 3

# %%
2e3
# Out:
# 2000.0

# %%
float('1.6')
# Out:
# 1.6

# %%
float('inf')
# Out:
# inf

# %%
float('-inf')
# Out:
# -inf

# %%
bool(0)
# Out:
# False

# %%
bool(-1)
# Out:
# True

# %%
bool('False')
# Out:
# True

# %%
a=None

# %%
a is None
# Out:
# True
